# %%
import pandas as pd

# %%
infile = 'IMDb movies.csv'

# %%
df = pd.read_csv(infile)

# %%
print(df.columns)
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
df.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
df.describe()
# Out:
#            duration      avg_vote         votes     metascore  \
# count  85855.000000  85855.000000  8.585500e+04  13305.000000
# mean     100.351418      5.898656  9.493490e+03     55.896881
# std       22.553848      1.234987  5.357436e+04     17.784874
# min       41.000000      1.000000  9.900000e+01      1.000000
# 25%       88.000000      5.200000  2.050000e+02     43.000000
# 50%       96.000000      6.100000  4.840000e+02     57.000000
# 75%      108.000000      6.800000  1.766500e+03     69.000000
# max      808.000000      9.900000  2.278845e+06    100.000000
#
#        reviews_from_users  reviews_from_critics
# count        78258.000000          74058.000000
# mean            46.040826             27.479989
# std            178.511411             58.339158
# min              1.000000              1.000000
# 25%              4.000000              3.000000
# 50%              9.000000              8.000000
# 75%             27.000000             23.000000
# ...

# %%
dfnometa = df[df['metascore'].isna()]
s = dfnometa['year']

# %%
dfnometa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72550 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          72550 non-null  object
#  1   title                  72550 non-null  object
#  2   original_title         72550 non-null  object
#  3   year                   72550 non-null  object
#  4   date_published         72550 non-null  object
#  5   genre                  72550 non-null  object
#  6   duration               72550 non-null  int64
#  7   country                72491 non-null  object
#  8   language               71744 non-null  object
#  9   director               72463 non-null  object
#  10  writer                 71000 non-null  object
#  11  production_company     68222 non-null  object
#  12  actors                 72486 non-null  object
#  13  description            70461 non-null  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %%
df[df['year']=='TV Movie 2019'].count()
# Out:
# imdb_title_id            1
# title                    1
# original_title           1
# year                     1
# date_published           1
# genre                    1
# duration                 1
# country                  1
# language                 1
# director                 1
# writer                   1
# production_company       1
# actors                   1
# description              1
# avg_vote                 1
# votes                    1
# budget                   0
# usa_gross_income         0
# worlwide_gross_income    0
# metascore                1
# reviews_from_users       1
# reviews_from_critics     1
# dtype: int64

# %%
df1=df['year']!='TV Movie 2019'

# %%
df1.value_counts()
# Out:
# True     85854
# False        1
# Name: year, dtype: int64

# %%
df1a = df[df1]

# %%
df1a.count()
# Out:
# imdb_title_id            85854
# title                    85854
# original_title           85854
# year                     85854
# date_published           85854
# genre                    85854
# duration                 85854
# country                  85790
# language                 85021
# director                 85767
# writer                   84282
# production_company       81399
# actors                   85785
# description              83739
# avg_vote                 85854
# votes                    85854
# budget                   23710
# usa_gross_income         15326
# worlwide_gross_income    31016
# metascore                13304
# reviews_from_users       78257
# reviews_from_critics     74057
# dtype: int64

# %%
series_years = df1a['year'].unique()

# %%
len(series_years)
# Out:
# 167

# %%
s=[]
for each_value in df1a['year']:
    s.append(int(each_value))

# %%
len(s)
# Out:
# 85854

# %%
s
# Out:
# [1894,
#  1906,
#  1911,
#  1912,
#  1911,
#  1912,
#  1919,
#  1913,
#  1912,
#  1912,
#  1913,
#  1913,
#  1913,
#  1913,
#  1914,
#  1914,
#  1913,
#  1914,
#  1913,
#  1913,
#  1913,
#  1915,
#  1914,
#  1914,
#  1914,
#  1914,
#  1913,
#  1914,
#  1914,
#  1915,
#  1914,
#  1914,
#  1915,
#  1914,
#  1914,
#  1914,
#  1914,
#  1914,
#  1914,
#  1914,
#  1915,
#  1914,
#  1914,
#  1914,
#  1914,
#  1915,
#  1915,
#  1915,
#  1915,
#  1915,
#  1915,
#  1915,
#  1915,
#  1916,
#  1915,
#  1915,
#  1915,
#  1915,
#  1915,
#  1917,
#  1915,
#  1915,
#  1915,
#  1916,
#  1916,
#  1915,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1918,
#  1916,
#  1917,
#  1917,
#  1917,
#  1917,
#  1918,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
# ...

# %%
df = df1a

# %%
df['intyear'] = s
# Out:
# <ipython-input-63-5bf9b32c3025>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['intyear'] = s

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85854 entries, 0 to 85854
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85854 non-null  object
#  1   title                  85854 non-null  object
#  2   original_title         85854 non-null  object
#  3   year                   85854 non-null  object
#  4   date_published         85854 non-null  object
#  5   genre                  85854 non-null  object
#  6   duration               85854 non-null  int64
#  7   country                85790 non-null  object
#  8   language               85021 non-null  object
#  9   director               85767 non-null  object
#  10  writer                 84282 non-null  object
#  11  production_company     81399 non-null  object
#  12  actors                 85785 non-null  object
#  13  description            83739 non-null  object
# ...

# %%
cols = {'intyear':'year_int'}
df=df.rename(cols, axis=1)

# %%
df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics', 'year_int'],
#       dtype='object')

# %%
df['year_int'].describe()
# Out:
# count    85854.000000
# mean      1993.500594
# std         24.216405
# min       1894.000000
# 25%       1979.000000
# 50%       2003.000000
# 75%       2013.000000
# max       2020.000000
# Name: year_int, dtype: float64

# %%
df_recent = df[df['year_int']>1985]

# %%
df_recent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60146 entries, 4334 to 85854
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          60146 non-null  object
#  1   title                  60146 non-null  object
#  2   original_title         60146 non-null  object
#  3   year                   60146 non-null  object
#  4   date_published         60146 non-null  object
#  5   genre                  60146 non-null  object
#  6   duration               60146 non-null  int64
#  7   country                60083 non-null  object
#  8   language               59560 non-null  object
#  9   director               60067 non-null  object
#  10  writer                 58835 non-null  object
#  11  production_company     56510 non-null  object
#  12  actors                 60088 non-null  object
#  13  description            58493 non-null  object
# ...

# %%
df_recent.groupby(df_recent['budget']).count()
# Out:
#              imdb_title_id  title  original_title  year  date_published  \
# budget
# $ 0                     12     12              12    12              12
# $ 1                      4      4               4     4               4
# $ 100                    1      1               1     1               1
# $ 1000                  21     21              21    21              21
# $ 10000                 95     95              95    95              95
# ...                    ...    ...             ...   ...             ...
# ZAR 5400000              1      1               1     1               1
# ZAR 6000000              1      1               1     1               1
# ZAR 7900000              1      1               1     1               1
# ZAR 8000000              3      3               3     3               3
# ZAR 8400000              1      1               1     1               1
#
#              genre  duration  country  language  director  ...  actors  \
# ...

# %%
df_recent.to_csv('IMDbBig_recent.csv')

# %%
df_recent.shape
# Out:
# (60146, 23)

# %%
s = ['$ 100', 'ZAR 100']

# %%
df_sample = df_recent.head(10)

# %%
df_sample['currency'] = df_sample['budget'].str.extract(r'(^. )')  # this is a regular expression that pulls the first character from the string field, regardless of what that character is.
# Out:
# <ipython-input-97-69c8915eefbe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sample['currency'] = df_sample['budget'].str.extract(r'(^. )')

# %%
df_sample['currency'].unique()
# Out:
# array(['$ ', nan], dtype=object)

# %%
df = df_recent

# %%
df[['budget_curr', 'budget_amt']] = df['budget'].str.split(expand=True)

# %%
df.head()
# Out:
#       imdb_title_id                       title              original_title  \
# 4334      tt0035423              Kate & Leopold              Kate & Leopold
# 14127     tt0064730  Nihon boryoku-dan: Kumicho  Nihon boryoku-dan: Kumicho
# 14159     tt0064820          Tutti contro Harry      The Plot Against Harry
# 14573     tt0066020                   7 xiao fu                   7 xiao fu
# 14739     tt0066498                  L'orecchio                        Ucho
#
#        year date_published                     genre  duration  \
# 4334   2001     2002-03-01  Comedy, Fantasy, Romance       118
# 14127  2000           1969             Action, Crime        97
# 14159  1989     1990-05-16                    Comedy        81
# 14573  1986     1986-06-28            Action, Comedy        80
# 14739  1990     1990-10-18           Drama, Thriller        94
#
#               country         language        director  ...  votes  \
# ...

# %%
df = df[df['budget_curr']=='$']
len(df)
# Out:
# 12824

# %%
s = df['budget_amt']
s.unique()
# Out:
# array(['48000000', '1535000', '2000000', '200000', '10000000', '15000',
#        '25000', '70000', '185000', '8800000', '18000000', '8500000',
#        '18500000', '5000000', '1500000', '12000000', '6500000', '60000',
#        '4000000', '11000000', '8700000', '25000000', '10500000',
#        '6000000', '7000000', '800000', '3500000', '15000000', '400000',
#        '13800000', '20000000', '14000000', '1100000', '3000000',
#        '8000000', '9000000', '1700000', '4500000', '6400000', '13000000',
#        '16000000', '600000', '37000000', '3401376', '40000000', '85000',
#        '250000', '24500000', '500000', '17000000', '2500000', '19000000',
#        '1900000', '1300000', '175000', '80000', '4700000', '3300000',
#        '4210000', '2700000', '180000', '350000', '1000000', '8300000',
#        '28000000', '1200000', '50000', '2300000', '75000', '29000000',
#        '1750000', '90000', '35000000', '3600000', '30000', '22000000',
# ...

# %%
t = []
for amt in s:
    budget_amt = int(amt)
    t.append(budget_amt)

# %%
len(t)
# Out:
# 12824

# %%
df['budget_int'] = t

# %%
df.count()
# Out:
# imdb_title_id            12824
# title                    12824
# original_title           12824
# year                     12824
# date_published           12824
# genre                    12824
# duration                 12824
# country                  12820
# language                 12752
# director                 12819
# writer                   12752
# production_company       12493
# actors                   12819
# description              12722
# avg_vote                 12824
# votes                    12824
# budget                   12824
# usa_gross_income          6525
# worlwide_gross_income     8113
# metascore                 5964
# reviews_from_users       12453
# reviews_from_critics     12044
# intyear                  12824
# budget_curr              12824
# budget_amt               12824
# budget_int               12824
# dtype: int64

# %%
ww_usa = df[['worlwide_gross_income', 'usa_gross_income']]

# %%
bothNull = not(pd.isna(ww_usa['worlwide_gross_income']) & pd.isna(ww_usa['usa_gross_income']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-c9e2fbcd3a04> in <module>
# ----> 1 bothNull = not(pd.isna(ww_usa['worlwide_gross_income']) & pd.isna(ww_usa['usa_gross_income']))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
len(bothNull)
# Out:
# 12824

# %%
bothNull.head()
# Out:
# 4334     False
# 19740     True
# 21434     True
# 21618     True
# 21931    False
# dtype: bool

# %%
atleastonegross = []
for value in bothNull:
    inverse = not(value)
    atleastonegross.append(inverse)

# %%
atleastonegross[:5]
# Out:
# [True, False, False, False, True]

# %%
df1 = df[atleastonegross] # selects the "True" rows 
len(df1)
# Out:
# 8113

# %%
outfile = 'output/big_filtered.xlsx'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8113 entries, 4334 to 85756
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          8113 non-null   object
#  1   title                  8113 non-null   object
#  2   original_title         8113 non-null   object
#  3   year                   8113 non-null   object
#  4   date_published         8113 non-null   object
#  5   genre                  8113 non-null   object
#  6   duration               8113 non-null   int64
#  7   country                8112 non-null   object
#  8   language               8088 non-null   object
#  9   director               8112 non-null   object
#  10  writer                 8095 non-null   object
#  11  production_company     8047 non-null   object
#  12  actors                 8111 non-null   object
#  13  description            8066 non-null   object
# ...

# %%
s =df1['worlwide_gross_income']
t = []
for value in s:
    int_value = int(value)
    t.append(int_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-761cffdd37da> in <module>
#       2 t = []
#       3 for value in s:
# ----> 4     int_value = int(value)
#       5     t.append(int_value)
#
# ValueError: invalid literal for int() with base 10: '$ 76019048'

# %%
infile='output/movies_big_filtered.csv'

# %%
df = pd.read_csv(infile)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8113 entries, 0 to 8112
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID_                    8113 non-null   int64
#  1   imdb_title_id          8113 non-null   object
#  2   title                  8113 non-null   object
#  3   original_title         8113 non-null   object
#  4   year                   8113 non-null   int64
#  5   date_published         8113 non-null   object
#  6   genre                  8113 non-null   object
#  7   duration               8113 non-null   int64
#  8   country                8112 non-null   object
#  9   language               8088 non-null   object
#  10  director               8112 non-null   object
#  11  writer                 8095 non-null   object
#  12  production_company     8047 non-null   object
#  13  actors                 8111 non-null   object
# ...

# %%
df['ROI_pct'] =100*(-1+df['worlwide_gross_income']/df['budget_int'])

# %%
df.head()
# Out:
#      ID_ imdb_title_id                title       original_title  year  \
# 0  81215     tt6793280  The Devil's Doorway  The Devil's Doorway  2018
# 1  52491    tt10183542    Firincinin Karisi    Firincinin Karisi  2019
# 2  61919     tt1783232           Fetih 1453           Fetih 1453  2012
# 3  31463     tt0122143   The Last Broadcast   The Last Broadcast  1998
# 4  54302     tt1127855              Ri-teon              Ri-teon  2007
#
#   date_published                   genre  duration      country language  ...  \
# 0      2/28/2019                  Horror        76  Ireland, UK  English  ...
# 1      9/27/2019                  Comedy        91       Turkey  Turkish  ...
# 2      2/16/2012  Action, Drama, History       162       Turkey  Turkish  ...
# 3     10/23/1998         Horror, Mystery        86          USA  English  ...
# 4       8/8/2007         Drama, Thriller       113  South Korea   Korean  ...
#
# ...

# %%
def outliers(df, column_name):
    quartiles = df[column_name].quantile([.25,.5,.75]) 
    lowerq = quartiles[0.25]                           
    upperq = quartiles[0.75]                           

    iqr = upperq-lowerq                                
    lower_bound = lowerq - (1.5*iqr)                   
    upper_bound = upperq + (1.5*iqr)                   

    #count the number of outliers in data set
    high_outliers_count = 0
    low_outliers_count = 0
    for value in df[column_name]:
        if (value > upper_bound):
            high_outliers_count += 1
        elif (value < lower_bound):
            low_outliers_count += 1


    numerator   = high_outliers_count+low_outliers_count
    denominator = len(df[column_name])
    ratio = numerator/denominator

    out_string = f'There are {numerator:,} out of {denominator:,} outliers, or {ratio:.0%}. {low_outliers_count} are below {lower_bound}, and {high_outliers_count} are above {upper_bound}'
    return out_string

# %%
outliers(df, 'ROI_pct')
# Out:
# 'There are 632 out of 8,113 outliers, or 8%. 0 are below -461.4241075, and 632 are above 557.5010458333334'

# %%
df['roi_outlier_ind']=df['ROI_pct']>557.50

# %%
df.to_csv(outfile)
